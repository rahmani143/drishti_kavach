# %% [markdown]
# # YOLOv8 Nano Model Training for License Plate Detection
# Run the cells below sequentially to install requirements, download your dataset, validate it, and train your model.

# %%
import torch
print("Visible GPUs:", torch.cuda.device_count())
# !pip uninstall -y ray
# Out:
# Visible GPUs: 1
# Found existing installation: ray 2.55.1
# Uninstalling ray-2.55.1:
#   Successfully uninstalled ray-2.55.1

# %%
# !pip install ultralytics pyyaml kaggle torch
# !pip install --upgrade ray ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 MB 26.3 MB/s eta 0:00:00:00:0100:01
# ...

# %%
import yaml

custom_data = {
    "train": [
        "/kaggle/input/datasets/adilshamim8/license-plate-recognition/train/train",
        "/kaggle/input/datasets/harshitsingh09/license-plate-detection-dataset-anpr-yolo-format/YOLO_dataset/images/train"
    ],
    "val": [
        "/kaggle/input/datasets/adilshamim8/license-plate-recognition/valid/valid",
        "/kaggle/input/datasets/harshitsingh09/license-plate-detection-dataset-anpr-yolo-format/YOLO_dataset/images/train"
    ],
    "nc": 1,
    "names": ["license_plate"]
}

yaml_path = "/kaggle/working/combined_perfect_plates.yaml"

with open(yaml_path, "w") as file:
    yaml.dump(custom_data, file)

print(f"Configuration saved to: {yaml_path}")
# Out:
# Configuration saved to: /kaggle/working/combined_perfect_plates.yaml

# %%
# import os
# import yaml
# from ultralytics import YOLO

# # ============================================================================
# # CORRECT CONFIGURATION SECTION (FOR KAGGLE)
# # ============================================================================

# # Path to the combined YAML file we generated from the Datacluster datasets
# DATASET_YAML = "/kaggle/working/combined_plates.yaml"

# # Training hyperparameters
# EPOCHS = 10           # Number of training epochs
# BATCH_SIZE = 32       # Optimized for Kaggle T4 GPUs
# IMG_SIZE = 640        # Image size for training
# DEVICE = [0, 1]       # Uses both Kaggle T4 GPUs for maximum speed
# MODEL = "yolov8n.pt"  # YOLOv8 nano model base

# %%
# import yaml

# # The exact, confirmed paths for both of your useful datasets
# custom_data = {
#     "train": [
#         "/kaggle/input/datasets/tkm22092/indian-number-plate-images/images/images",
#         "/kaggle/input/datasets/dataclusterlabs/indian-number-plates-dataset/Indian_Number_Plates/Sample_Images"
#     ],
#     "val": [
#         "/kaggle/input/datasets/tkm22092/indian-number-plate-images/images/images",
#         "/kaggle/input/datasets/dataclusterlabs/indian-number-plates-dataset/Indian_Number_Plates/Sample_Images"
#     ],
#     "nc": 1,
#     "names": ["license_plate"]
# }

# yaml_path = "/kaggle/working/combined_plates.yaml"

# with open(yaml_path, "w") as file:
#     yaml.dump(custom_data, file)

# print(f"Unified configuration saved to: {yaml_path}")

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model.train(
    data="/kaggle/working/combined_perfect_plates.yaml",  
    epochs=200,      # Increased for actual learning
    batch=32,       
    imgsz=640,
    device=0,       
    workers=2,      
    cache=True,     
    plots=False,    
    val=False       
)


from pathlib import Path

# ============================================================================
# CORRECTED CONFIGURATION SECTION
# ============================================================================

# YOLOv8 defaults to 'train' for the first run inside runs/detect/
run_dir = Path("runs/detect/train")
best_weights = run_dir / "weights/best.pt"
last_weights = run_dir / "weights/last.pt"

print("="*70)
print("Training Complete!")
print("="*70)

# Verify and print the best weights location
if best_weights.exists():
    print(f"Best weights saved at:\n  {best_weights.absolute()}")
else:
    print("Best weights file not found. Check the training logs above.")

# Verify and print the last checkpoint location
if last_weights.exists():
    print(f"\nLast checkpoint saved at:\n  {last_weights.absolute()}")

# Print the master directory
print(f"\nAll training artifacts saved at:\n  {run_dir.absolute()}")
print("="*70)


import os
from IPython.display import FileLink, display

# Search for the most recently generated best.pt file
best_pt_path = None
for root, dirs, files in os.walk('/kaggle/working/runs/detect/'):
    if 'best.pt' in files:
        best_pt_path = os.path.join(root, 'best.pt')

if best_pt_path:
    print("Found your model! Click the link below to download:")
    # Create a relative path for the Kaggle download link
    relative_path = os.path.relpath(best_pt_path, '/kaggle/working')
    display(FileLink(relative_path))
else:
    print("Model not found. Did the training finish completely?")
# Out:
# Ultralytics 8.4.58 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# Out:
# ...
# Training Complete!
# ...
# Best weights file not found. Check the training logs above.
#
# All training artifacts saved at:
#   /kaggle/working/runs/detect/train
# ...

# %%
# Out:
# Model not found. Did the training finish completely?
